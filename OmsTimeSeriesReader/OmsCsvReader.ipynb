# %%
import pandas as pd

# %% [markdown]
# Skiprows va messo uguale al numero di riga dove si trova 'Type,Date,Double...Double'. Generalmente skiprows = 6 per le intestazioni di Oms di 8 righe

# %%
df= pd.read_csv('/home/drugo/Desktop/Temperature.csv',sep=',',skiprows=6,low_memory=False)

# %%
df
# Out:
#          Type              Date    Double  Double.1  Double.2  Double.3  \
# 0      Format  yyyy-MM-dd HH:mm       NaN       NaN       NaN       NaN
# 1         NaN  1994-01-01 00:00 -1.197894 -1.184371 -1.126312 -1.077579
# 2         NaN  1994-01-01 01:00 -1.128938 -1.151049 -1.246847 -1.251899
# 3         NaN  1994-01-01 02:00 -1.193374 -1.209497 -1.280602 -1.278515
# 4         NaN  1994-01-01 03:00 -1.034343 -1.049266 -1.115605 -1.128459
# 5         NaN  1994-01-01 04:00 -0.777482 -0.778611 -0.785766 -0.787632
# 6         NaN  1994-01-01 05:00 -0.545713 -0.544823 -0.544289 -0.556123
# 7         NaN  1994-01-01 06:00 -0.263907 -0.262621 -0.260066 -0.265510
# 8         NaN  1994-01-01 07:00 -0.051486 -0.051602 -0.054994 -0.041844
# 9         NaN  1994-01-01 08:00 -0.015121 -0.015615 -0.023387 -0.013062
# 10        NaN  1994-01-01 09:00  0.152210  0.152678  0.148909  0.140701
# 11        NaN  1994-01-01 10:00  0.761441  0.755790  0.727217  0.703857
# ...

# %%
Data = df.iloc[1:,1:]

# %%
Data = Data.set_index('Date')

# %%
Data
# Out:
#                     Double  Double.1  Double.2  Double.3  Double.4  Double.5  \
# Date
# 1994-01-01 00:00 -1.197894 -1.184371 -1.126312 -1.077579 -0.985325 -0.715638
# 1994-01-01 01:00 -1.128938 -1.151049 -1.246847 -1.251899 -1.094557 -0.926416
# 1994-01-01 02:00 -1.193374 -1.209497 -1.280602 -1.278515 -1.154255 -1.014378
# 1994-01-01 03:00 -1.034343 -1.049266 -1.115605 -1.128459 -1.027676 -0.924705
# 1994-01-01 04:00 -0.777482 -0.778611 -0.785766 -0.787632 -0.746529 -0.673066
# 1994-01-01 05:00 -0.545713 -0.544823 -0.544289 -0.556123 -0.562595 -0.569182
# 1994-01-01 06:00 -0.263907 -0.262621 -0.260066 -0.265510 -0.274464 -0.278593
# 1994-01-01 07:00 -0.051486 -0.051602 -0.054994 -0.041844  0.005350  0.107077
# 1994-01-01 08:00 -0.015121 -0.015615 -0.023387 -0.013062  0.032827  0.125659
# 1994-01-01 09:00  0.152210  0.152678  0.148909  0.140701  0.163152  0.213102
# 1994-01-01 10:00  0.761441  0.755790  0.727217  0.703857  0.741550  0.776457
# ...
