# %% [markdown]
# Reading Input files
# ====

# %%
import os
import numpy as np
import rasterio
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd

# %%
os.getcwd()
# Out:
# '/home/drugo/PythonScript/LaiReader'

# %%
os.chdir('/home/drugo/Sim/kriging_simulations/kriging_simulations/output')

# %%
os.listdir()
# Out:
# ['2_SWRB_Raster',
#  'hack_cut.prj',
#  'c_tangenziale.prj',
#  'drain_dir.asc',
#  'DEM_LORES2.asc.aux.xml',
#  'fake1.tif',
#  '1_extract_network',
#  'kriging_interpolated_20080722_1500.asc.aux.xml',
#  'LwrbUpWellingRaster.prj',
#  'EV_T.csv',
#  'distances_WIND.csv',
#  'EV_H.csv',
#  'SWRB_raster.asc',
#  'net_cut.shp',
#  'kriging_interpolated_RH_local_20080722_1500.prj',
#  'kriging_interpolated_HR_20080722_1500.asc',
#  'tc9.prj',
#  'c_planare.prj',
#  'Krigings_raster',
#  'net_cut.prj',
#  'rain_maggio',
#  'TV_giugno_bessel_RHMEAN.csv',
#  'kriging_interpolated_HR_20080722_1500.prj',
#  'Wind.asc',
#  'c_planare.asc',
#  'DEM_LORES3.prj',
#  'temperature',
#  'c_longitudinale.prj',
#  'net_cut.shx',
#  'mybasin.asc',
#  'rescaled_distance.asc',
#  'ET_SO_raster',
#  'flow_dir.prj',
#  'kriging_interpolated_HRlocal_20080722_1500.asc.aux.xml',
#  'tc3.asc',
#  'EV_RH.csv',
#  'top_index.prj',
#  'kriging_interpolated_temp_20080722_1500.prj',
#  'LwrbDownWellingRaster.prj',
#  'Tca.prj',
#  'ET_raster.prj',
#  'fake2.prj',
#  'net_number_cut.asc',
#  'SWRB_raster',
#  '1_drain_dir',
#  'SWRB_raster.asc.aux.xml',
#  'EV_WIND.csv',
#  'c_longitudinale.asc',
#  '1_net_attributes_builder',
#  'network_1000.prj',
#  'drain_dir.prj',
#  'netRadiationRaster.prj',
#  'net_number_cut.prj',
#  'slope.asc',
#  '1_pitfiller',
#  'fake2.asc',
#  'pitfiller_full.asc',
#  'LWRB_raster',
#  'pitfiller.asc',
#  'DEM_LORES.tif',
#  'DEM_LORES.prj',
#  'LwrbDownWellingRaster.asc',
#  'mybasin.prj',
#  'distances_H.csv',
#  'ET_raster.asc',
#  'tc3.prj',
#  'kriging_interpolated_20080722_1500.prj',
#  'distances_RHMEAN.csv',
#  'net_cut.fix',
#  'TV_giugno_bessel.csv',
#  'EtPtRaster.asc',
#  'skyview_lowres.asc',
#  'Isarco_cut.prj',
#  '2_skyview',
#  'ET_raster.asc.aux.xml',
#  'Temperature',
#  'LwrbUpWellingRaster.asc',
#  'fake.asc',
#  '1_tc',
#  'skyview_Isarco.prj',
#  '1_water_outlet',
#  'netRadiationRaster',
#  '1_top_index',
#  'c_tangenziale.asc',
#  '1_slope',
#  '1_curvature',
#  'DEM_LORES2.asc',
#  'tc9.asc',
#  'kriging_interpolated_20080722_1500.asc',
#  'basin.asc',
#  'pitfiller_small.prj',
#  'Krigings_raster_T',
#  'Krigings_raster_rain',
#  'pitfiller.prj',
#  'netRadiationRaster.asc.aux.xml',
#  '1_mark_outlet',
#  'mark_outlet.asc',
#  'EV',
#  'kriging_interpolated_temp_20080722_1500.asc',
#  'netRadiationRaster.asc',
#  '2_SWRB_Isarco',
#  'subbasins_cut.asc',
#  'skyview_lowres.prj',
#  'DEM_LORES.asc',
#  'hack_cut.asc',
#  'rescaled_distance.prj',
#  'kriging_interpolated_RH_local_20080722_1500.asc',
#  'kriging_interpolated_WINDlocal_20080722_1500.prj',
#  'pitfiller_small.asc',
#  '1_rescaled_distance',
#  'tv',
#  'skyview_small.prj',
#  'network_1000.asc',
#  'slope.prj',
#  'DEM_LORES2.prj',
#  'flow_dir.asc',
#  'skyview_small.asc',
#  'skyview_Isarco.asc',
#  '1_cutout',
#  '1_net_numbering',
#  'DEM_LORES3.asc.aux.xml',
#  '3_EV',
#  'Isarco_mask.asc',
#  'top_index.asc',
#  'kriging_interpolated_WINDlocal_20080722_1500.asc',
#  'DEM_LORES3.asc',
#  'ET_SO',
#  'EtPtRaster.prj',
#  'Pressure.asc',
#  'Rain_maggio',
#  'LeafAreaIndex.asc',
#  'pitfiller_full.prj',
#  'Isarco_cut.asc',
#  'net_cut.dbf',
#  'Rain_giugno',
#  'net_cut.qix',
#  'ET_PriestleyTaylor_Raster',
#  'TV',
#  'SWRB_raster.prj',
#  'mark_outlet.prj',
#  'distances_T.csv',
#  '1_flow_direction',
#  'distances_RH.csv',
#  'Tca.asc',
#  'subbasins_cut.prj',
#  'EV_RHMEAN.csv',
#  'basin.prj']

# %%
with rasterio.open("ET_raster.asc") as src:
    ET=src.read(1)

# %%
src
# Out:
# <closed RasterReader name='ET_raster.asc' mode='r'>

# %%
plt.imshow(ET)

# %%
ET.view()
# Out:
# array([[-9.9990000e+03, -9.9990000e+03, -9.9990000e+03, ...,
#         -9.9990000e+03, -9.9990000e+03, -9.9990000e+03],
#        [-9.9990000e+03,  7.9241134e-03,  5.8819866e-03, ...,
#          3.6842339e-02,  1.3610412e-02, -9.9990000e+03],
#        [-9.9990000e+03,  9.3043130e-03,  7.8313900e-03, ...,
#          3.4106482e-02,  4.4814795e-02, -9.9990000e+03],
#        ...,
#        [-9.9990000e+03,  5.9449688e-02,  7.5754806e-02, ...,
#          1.9077232e-01,  1.2953533e-01, -9.9990000e+03],
#        [-9.9990000e+03,  4.6997834e-02,  5.2854054e-02, ...,
#          1.3805367e-01,  1.0962498e-01, -9.9990000e+03],
#        [-9.9990000e+03, -9.9990000e+03, -9.9990000e+03, ...,
#         -9.9990000e+03, -9.9990000e+03, -9.9990000e+03]], dtype=float32)

# %%
ET = np.array(ET, dtype='f')

# %%
amin=min(ET[ET > 0])
amin
# Out:
# 0.0003799094

# %%
ET[ET == -9999]='NAN'
ET
# Out:
# array([[       nan,        nan,        nan, ...,        nan,        nan,
#                nan],
#        [       nan, 0.00792411, 0.00588199, ..., 0.03684234, 0.01361041,
#                nan],
#        [       nan, 0.00930431, 0.00783139, ..., 0.03410648, 0.0448148 ,
#                nan],
#        ...,
#        [       nan, 0.05944969, 0.07575481, ..., 0.19077232, 0.12953533,
#                nan],
#        [       nan, 0.04699783, 0.05285405, ..., 0.13805367, 0.10962498,
#                nan],
#        [       nan,        nan,        nan, ...,        nan,        nan,
#                nan]], dtype=float32)

# %%
plt.imshow(ET)

# %%
fig,ax = plt.subplots()
ax.imshow(ET,cmap="rainbow")
ax.set_aspect(1)

# %%
fET=ET.flatten()
cfET=pd.DataFrame(fET[~np.isnan(fET)])

# %%
cfET.describe()
# Out:
#                   0
# count  3.461304e+06
# mean   2.174068e+00
# std    1.584722e+00
# min    0.000000e+00
# 25%    1.000000e+00
# 50%    1.600000e+00
# 75%    2.800000e+00
# max    7.000000e+00

# %%
cflai.hist(label="Distribution of leaf area index", normed=True)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fe898df76a0>]],
#       dtype=object)

# %%
fig,ax = plt.subplots()
ax.imshow(ET,cmap="rainbow")
ax.set_aspect(1)
